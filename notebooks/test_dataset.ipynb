# %% [markdown]
# # WikiStories Dataset

# %%
# get sample story from MongoDB
DB_NAME = 'wiki_stories'
COL_NAME = 'biographies_trees'  # all, biographies, biographies_trees

from pymongo import MongoClient
mongo_client = MongoClient()[DB_NAME]
count = mongo_client[COL_NAME].count_documents({})
print ("%d dialogues in %s" % (count, COL_NAME))

mongo_client[COL_NAME].find_one()
# Out:
# 1054 dialogues in biographies
# {'_id': 'https://en.wikipedia.org/wiki/George_Washington',
#  'cid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q23'},
#  'article': {'type': 'uri',
#   'value': 'https://en.wikipedia.org/wiki/George_Washington',
#   'summary': {'labels': ['Founding_Fathers_of_the_United_States',
#     'President_of_the_United_States',
#     'Patriot_(American_Revolution)',
#     'American_Revolutionary_War',
#     'Constitutional_Convention_(United_States)',
#     'French_and_Indian_War',
#     'Continental_Congress',
#     'Commanding_General_of_the_United_States_Army',
#     'Continental_Army',
#     'Siege_of_Yorktown',
#     'United_States_Constitution',
#     'United_States_Electoral_College',
#     'Thomas_Jefferson',
#     'Alexander_Hamilton',
#     'French_Revolution',
#     'Jay_Treaty',
#     'George_Washington%27s_Farewell_Address',
#     'Freemasonry'],
#    'URIs': ['Q186539',
#     'Q11696',
#     'Q1365374',
#     'Q40949',
# ...
