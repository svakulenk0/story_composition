# %%
artists_urls = ['https://en.wikipedia.org/wiki/Frans_Hals', 'https://en.wikipedia.org/wiki/Johannes_Vermeer', 'https://en.wikipedia.org/wiki/Jan_Steen', 'https://en.wikipedia.org/wiki/Rembrandt', 'https://en.wikipedia.org/wiki/Jan_Asselijn', 'https://en.wikipedia.org/wiki/Bartholomeus_van_der_Helst']
objects_urls = ['https://en.wikipedia.org/wiki/The_Night_Watch', 'https://en.wikipedia.org/wiki/The_Threatened_Swan', 'https://en.wikipedia.org/wiki/The_Milkmaid_(Vermeer)', 'https://en.wikipedia.org/wiki/The_Jewish_Bride']
urls = artists_urls
print(urls[0])
# Out:
# https://en.wikipedia.org/wiki/Frans_Hals

# %%
from newspaper import Article

texts = []

for url in urls:
    a = Article(url, language='en')
    try:
        a.download()
        a.parse()
        title = a.title
        text = a.text
        texts.append(text)
    except:
        pass

# %%
# collect headlines as short paragraphs
headlines = []
p_lens = []
for i, text in enumerate(texts):
    print(urls[i])
    # show text shape as signal for headers and structure
    paragraphs = [p for p in text.split('\n') if p]
    
    # headlines of the document
    hs = []
    for j, p in enumerate(paragraphs):
#         print(p)
#         if p:
#             print(len(p))
        # paragraph length in terms of number of words
        p_len = len(p.split())
#             print(p_len)
        # heuristic to select headlines: less than 10 words followed by a longer paragraph (to avoid parsing tables and lists)
        if p_len < 10 and len(paragraphs) > j+1:
            # next paragraph
            next_p = paragraphs[j+1]
#             print(next_p)
#             if len(next_p.split()) > 10:
            print(p)
            hs.append(p)
        p_lens.append(p_len)
        
    print("/"*100)  # document break next document
    
    # drop duplicate headlines
    hs = list(set(hs))
    # keep headlines grouped per doc
    if hs:
        headlines.append(hs)
# Out:
# https://en.wikipedia.org/wiki/Frans_Hals
# 17th-century painter from the Northern Netherlands
# Biography [ edit ]
# Statue of Frans Hals in Florapark, Haarlem
# Artistic career [ edit ]
# Wedding portraits [ edit ]
# 1626
# 1631
# 1633
# 1635
# 1645
# 1645
# 1655
# 1665
# Portrait painter [ edit ]
# Willem Heythuijsen by Frans Hals 1634
# Painting technique [ edit ]
# Influence [ edit ]
# Legacy [ edit ]
# Public collections (selection) [ edit ]
# See also [ edit ]
# References [ edit ]
# Further reading [ edit ]
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# https://en.wikipedia.org/wiki/Johannes_Vermeer
# 17th-century Dutch painter
# "Vermeer" redirects here. For other uses, see Vermeer (disambiguation)
# Pronunciation of name [ edit ]
# The usual English pronunciation is .[9][10][11]
# Life [ edit ]
# Youth and heritage [ edit ]
# Marriage and family [ edit ]
# Career [ edit ]
# Wars and death [ edit ]
# Style [ edit ]
# ...

# %%
# get the Wiki article html page and extract section headings
import requests
import scrape

page = requests.get(sample_article).text

# collect the sequence of URLs and the corresponding WikiData IDs
def get_wiki_sequence(scraper):
    '''
    scraper is a function extracting links from a Wiki page
    '''
    URIs = []
    links = scraper(page)
    for link in links:
        _, URI = link_wiki_data(link['url'])
        # skip entities missing from WikiData
        if URI != '-1':
            URIs.append(URI)
#             print(URI)
    return URIs

print("Extracting story sequence")

# get only the links from the article without the summary
story_URIs = get_wiki_sequence(scrape.extract_story_links)
print("%d story URIs extracted"%len(story_URIs))
# print(story_URIs)
# Out:
# Extracting story sequence
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e72a7bd18810> in <module>()
#      28
#      29 # get only the links from the article without the summary
# ---> 30 story_URIs = get_wiki_sequence(scrape.extract_story_links)
#      31 print("%d story URIs extracted"%len(story_URIs))
#      32 # print(story_URIs)
#
# <ipython-input-2-e72a7bd18810> in get_wiki_sequence(scraper)
#      12     '''
#      13     URIs = []
# ---> 14     links = scraper(page)
#      15     for link in links:
#      16         _, URI = link_wiki_data(link['url'])
#
# /home/svakule/story_composition/notebooks/scrape.py in extract_story_links(page)
#     233     body = get_paragraphs(body)
#     234
# --> 235     return extract_links(body)
#     236
#     237
#
# /home/svakule/story_composition/notebooks/scrape.py in extract_links(page)
#     189     """
# ...
